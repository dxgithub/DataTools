# %%
img_root = 'E:/Data/WIDER_face/WIDER_train/images/'
infos = [line.strip('\n') for line in open("E:/Data/WIDER_face/wider_face_train.txt") ]
N=len(infos)
view_idx=0
f=open("E:/Data/WIDER_face/Regreessed_wider_face_train.txt",'w')

# %%
for info in infos:
    #print(info)
    if "Chid" in info or "Group_Photo" in info or "YiCheng" in info or "FaceG" in info:
        view_idx=view_idx+1
        info_strlist = info.split(' ')
        img_name =img_root+info_strlist[0]+".jpg"
        print(img_name)
# Out:
# E:/Data/WIDER_face/WIDER_train/images/63--Chid/0008D5303C57B05D3EA394FC3D555E13_1.jpg
# E:/Data/WIDER_face/WIDER_train/images/63--Chid/000C510984520E25B58B838D47D6A099_1.jpg
# E:/Data/WIDER_face/WIDER_train/images/63--Chid/000E5E2D433D8FF25C629A8B7D4357F5_1.jpg
# E:/Data/WIDER_face/WIDER_train/images/63--Chid/001588C176596B2776E9A30A425E9623_1.jpg
# E:/Data/WIDER_face/WIDER_train/images/63--Chid/0019EAE7A9880BC8473B255E00C41B17_1.jpg
# E:/Data/WIDER_face/WIDER_train/images/63--Chid/001CAA980FDCDA7EF716629C8A85A39B_1.jpg
# E:/Data/WIDER_face/WIDER_train/images/63--Chid/001E633E3D8850BFEB7401D443B239D2_1.jpg
# E:/Data/WIDER_face/WIDER_train/images/63--Chid/002343839508D4707176BF5B817E8248_1.jpg
# E:/Data/WIDER_face/WIDER_train/images/63--Chid/00272D8E4B385BF00D2C9CCF0185913A_1.jpg
# E:/Data/WIDER_face/WIDER_train/images/63--Chid/002D3E228253BD7A3801B7CD7EFDAF00_1.jpg
# E:/Data/WIDER_face/WIDER_train/images/63--Chid/0030456747D848DC2821C5BF4F574034_1.jpg
# ...
